# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
def CreateScheduler():
    
    df = pd.read_excel("workingdays.xlsx")
    df['Year'] = pd.DatetimeIndex(df['Date']).year
    df['Month'] = pd.DatetimeIndex(df['Date']).month
    df.index = df['Date']
    df_workingdays = df.groupby(['Year','Month'])['IsWorkingDay'].cumsum().reset_index()
    df_workingdays.index = df['Date']
    
    df_unique_workingdays = pd.merge(df, df_workingdays, left_index=True, right_index=True)
    df_unique_workingdays.reset_index(inplace=True)
    df_unique_workingdays.drop(columns=['Date_x','Date_y'],inplace=True)


    for column in df_unique_workingdays:
        if '_x' in column:
            df_unique_workingdays.drop(columns=column,inplace=True)
        
    df_unique_workingdays.columns = df_unique_workingdays.columns.str.replace('_y','')
    
    df_workingdays = df_unique_workingdays.groupby(['IsWorkingDay','Year','Month'])['Date'].agg("min",'Date').reset_index()
    df_workingdays.sort_values(by='Date',inplace=True)
    df_workingdays.reset_index(inplace=True)
    
    df_workingdays.to_excel('Workingdays_cleansed.xlsx',index=False)

    return df_workingdays

# %%
df = pd.read_excel("workingdays.xlsx")
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month
df_workingdays = df.groupby(['Year','Month'])['IsWorkingDay'].cumsum().reset_index()
df_unique_workingdays = pd.merge(df, df_workingdays, left_index=True, right_index=True)
df_unique_workingdays.reset_index(inplace=True)
#df_unique_workingdays.drop(columns=['level_0','Date_y'],inplace=True)
df_unique_workingdays

for column in df_unique_workingdays:
    if '_x' in column:
        df_unique_workingdays.drop(columns=column,inplace=True)
    
df_unique_workingdays.columns = df_unique_workingdays.columns.str.replace('_y','')

df_unique_workingdays
df_workingdays = df_unique_workingdays.groupby(['IsWorkingDay','Year','Month'])['Date'].agg("min").reset_index()
df_workingdays
df_workingdays.sort_values(by='Date',inplace=True)
df_workingdays.reset_index(inplace=True)
df_workingdays
# Out:
#      index  IsWorkingDay  Year  Month       Date
# 0        3             1  2021      1 2021-01-01
# 1       16             2  2021      1 2021-01-04
# 2       29             3  2021      1 2021-01-05
# 3       41             4  2021      1 2021-01-06
# 4       53             5  2021      1 2021-01-07
# ..     ...           ...   ...    ...        ...
# 261    263            22  2021     12 2021-12-30
# 262    265            23  2021     12 2021-12-31
# 263      2             0  2022      1 2022-01-01
# 264     15             1  2022      1 2022-01-03
# 265     28             2  2022      1 2022-01-04
#
# [266 rows x 5 columns]

# %%
schedule = CreateScheduler()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16428/1121667885.py in <module>
# ----> 1 schedule = CreateScheduler()
#
# ~\AppData\Local\Temp/ipykernel_16428/473169804.py in CreateScheduler()
#      19     df_unique_workingdays.columns = df_unique_workingdays.columns.str.replace('_y','')
#      20
# ---> 21     df_workingdays = df_unique_workingdays.groupby(['IsWorkingDay','Year','Month'])['Date'].agg("min",'Date').reset_index()
#      22     df_workingdays.sort_values(by='Date',inplace=True)
#      23     df_workingdays.reset_index(inplace=True)
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     241
#     242         if isinstance(func, str):
# --> 243             return getattr(self, func)(*args, **kwargs)
#     244
#     245         elif isinstance(func, abc.Iterable):
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\groupby.py in min(self, numeric_only, min_count)
#    1870     @doc(_groupby_agg_method_template, fname="min", no=False, mc=-1)
#    1871     def min(self, numeric_only: bool = False, min_count: int = -1):
# -> 1872         return self._agg_general(
#    1873             numeric_only=numeric_only, min_count=min_count, alias="min", npfunc=np.min
#    1874         )
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1362         with group_selection_context(self):
#    1363             # try a cython aggregation if we can
# -> 1364             result = self._cython_agg_general(
#    1365                 how=alias,
#    1366                 alt=npfunc,
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     330         if numeric_only and not is_numeric_dtype(obj.dtype):
#     331             # GH#41291 match Series behavior
# --> 332             raise NotImplementedError(
#     333                 f"{type(self).__name__}.{how} does not implement numeric_only."
#     334             )
#
# NotImplementedError: SeriesGroupBy.min does not implement numeric_only.

# %%
current_working_day = schedule[schedule['Date'] == datetime.today().date().isoformat()]
#current_working_day = pd.DataFrame()

if not current_working_day.empty:
    print('Today,',datetime.today().date().isoformat(),',is considered a working day!')
else:
    print('No, today we do not work!')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16428/2285496210.py in <module>
# ----> 1 schedule = CreateScheduler()
#       2
#       3 current_working_day = schedule[schedule['Date'] == datetime.today().date().isoformat()]
#       4 #current_working_day = pd.DataFrame()
#       5 if not current_working_day.empty:
#
# ~\AppData\Local\Temp/ipykernel_16428/473169804.py in CreateScheduler()
#      19     df_unique_workingdays.columns = df_unique_workingdays.columns.str.replace('_y','')
#      20
# ---> 21     df_workingdays = df_unique_workingdays.groupby(['IsWorkingDay','Year','Month'])['Date'].agg("min",'Date').reset_index()
#      22     df_workingdays.sort_values(by='Date',inplace=True)
#      23     df_workingdays.reset_index(inplace=True)
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     241
#     242         if isinstance(func, str):
# --> 243             return getattr(self, func)(*args, **kwargs)
#     244
#     245         elif isinstance(func, abc.Iterable):
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\groupby.py in min(self, numeric_only, min_count)
#    1870     @doc(_groupby_agg_method_template, fname="min", no=False, mc=-1)
#    1871     def min(self, numeric_only: bool = False, min_count: int = -1):
# -> 1872         return self._agg_general(
#    1873             numeric_only=numeric_only, min_count=min_count, alias="min", npfunc=np.min
#    1874         )
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1362         with group_selection_context(self):
#    1363             # try a cython aggregation if we can
# -> 1364             result = self._cython_agg_general(
#    1365                 how=alias,
#    1366                 alt=npfunc,
#
# ~\AppData\Local\pypoetry\Cache\virtualenvs\workingdayscheduler-sCPMcqc3-py3.9\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     330         if numeric_only and not is_numeric_dtype(obj.dtype):
#     331             # GH#41291 match Series behavior
# --> 332             raise NotImplementedError(
#     333                 f"{type(self).__name__}.{how} does not implement numeric_only."
#     334             )
#
# NotImplementedError: SeriesGroupBy.min does not implement numeric_only.

# %%
df = pd.DataFrame()
